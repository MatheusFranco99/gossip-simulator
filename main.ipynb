# %%
from simulator import Simulator
sim = Simulator(num_nodes = 100, rho = 1.1, cobra_walk_rho=0.8)
sim.setup()
sim.show_network()
results = sim.run()
print(results)
# Out:
# [1.0153355649443716, 1.0328516646643, 1.307770623155193, 1.3496709901362673, 2.439117762563946, 2.3216231238553133, 2.2922137237086773, 1.5223639631709849, 2.004052833410703, 3.203732071264839, 1.9059203399057707, 2.3261985142288824, 3.136146983540555, 4.158324820971495, 13.033305670202628, 1.995329834775331, 1.3316258513469519, 4.194638097028035, 1.5539940365305902, 1.948862331658356, 7.0594355110765115, 1.9222840372146166, 2.5177467870508226, 3.4751011123954973, 1.5034713333451175, 1.774122575458642, 3.4377080625260983, 5.921002910022189, 2.0806801727597843, 5.249123540473155, 2.1363176913770223, 6.956609336940003, 1.7906650427237412, 2.0058016510416947, 4.2490503353442675, 1.48409941973178, 1.6266840427427818, 3.3714501284198017, 4.154859884551725, 3.3233206867316247, 4.371186053551018, 2.3732662932115725, 3.422915257830864, 1.4406009781506133, 3.1352184311517406, 3.043601584313834, 3.2280407359040715, 4.340294822537978, 3.15882639364443, 7.007694544360433, 3.0359477705800235, 2.7
# ...

# %%
import numpy as np
print(max(results))
print(min(results))
print(np.mean(results))
print(np.median(results))
# Out:
# 13.033305670202628
# 1.0153355649443716
# 2.8969313285496545
# 2.440777876481584
